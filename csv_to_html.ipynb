# %%
import pandas as pd

# %%
df = pd.read_csv('Cities.csv')
df.head()
# Out:
#    ID        Lat         Lng       City Country  Max Temp  Hum  Cloud   Wind
# 0   0   3.155820  -12.931031   monrovia      lr     89.60   66     40  13.87
# 1   1  54.821781  121.202196     amazar      ru     33.52   65      8   2.37
# 2   2 -50.151464  125.745289  esperance      au     51.52   83      0   5.73
# 3   3 -43.156015  -86.781602     castro      cl     50.53  100     88   3.27
# 4   5  38.315204 -111.477799      price      us     46.40   42     20   5.82

# %%
html_table=df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>ID</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Max Temp</th>\n      <th>Hum</th>\n      <th>Cloud</th>\n      <th>Wind</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>3.155820</td>\n      <td>-12.931031</td>\n      <td>monrovia</td>\n      <td>lr</td>\n      <td>89.60</td>\n      <td>66</td>\n      <td>40</td>\n      <td>13.87</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>54.821781</td>\n      <td>121.202196</td>\n      <td>amazar</td>\n      <td>ru</td>\n      <td>33.52</td>\n      <td>65</td>\n      <td>8</td>\n      <td>2.37</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>-50.151464</td>\n      <td>125.745289</td>\n      <td>esperance</td>\n      <td>au</td>\n      <td>51.52</td>\n      <td>83</td>\n      <td>0</td
# ...

# %%
df.to_html("Cities.html")
